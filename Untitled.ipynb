# %%
import numpy as np
import itertools
from itertools import permutations
from itertools import combinations
from itertools import product
import matplotlib.pyplot as plt
import sympy as sp
import copy

#MesonParticle = [coefficient, [flavorstructure]]
pip = [1, [2.2, 1]]
pipB = [1, [1.2, 2]]
pi0 = [[1/(sp.sqrt(2)), [2.2, 2]], [-1/(sp.sqrt(2)), [1.2, 1]]]
pi0B = [[1/(sp.sqrt(2)), [2.2, 2]], [-1/(sp.sqrt(2)), [1.2, 1]]]
pim = [-1, [1.2, 2]]
pimB = [-1, [2.2, 1]]
eta0 = [[1, [2.2, 2]], [1, [1.2, 1]]]
eta0B = [[1, [2.2, 2]], [1, [1.2, 1]]]
kaonp = [1, [3.2, 1]]
kaonpB = [1, [1.2, 3]]
kaonm = [1, [3.2, 2]]
kaonmB = [1, [2.2, 3]]
phi0 = [1, [3.2, 3]]
phi0B = [1, [3.2, 3]]

#BaryonParticle = [coefficient, [flavorstructure]]
deltapp = [1, [1, 1, 1]]
deltappB = [1, [1.2, 1.2, 1.2]]
deltap = [sp.sqrt(3), [1, 1, 2]]
deltapB = [sp.sqrt(3), [2.2, 1.2, 1.2]]
delta0 = [sp.sqrt(3), [1, 2, 2]]
delta0B = [sp.sqrt(3), [2.2, 2.2, 1.2]]
deltam = [1, [2, 2, 2]]
deltamB = [1, [2.2, 2.2, 2.2]]
sigmap = [1, [1, 1, 3]]
sigmapB = [1, [3.2, 1.2, 1.2]]
sigma0 = [sp.sqrt(2), [1, 2, 3]]
sigma0B = [sp.sqrt(2), [3.2, 2.2, 1.2]]
sigmam = [1, [2, 2, 3]]
sigmamB = [1, [3.2, 2.2, 2.2]]
nucleonp = [1, [1, 1, 2]]
nucleonpB = [1, [2.2, 1.2, 1.2]]
nucleon0 = [-1, [2, 2, 1]]
nucleon0B = [-1, [1.2, 2.2, 2.2]]
xi0 = [1, [3, 3, 1]]
xi0B = [1, [1.2, 3.2, 3.2]]
xim = [1, [3, 3, 2]]
ximB = [1, [2.2, 3.2, 3.2]]
lambda0 = [1, [1, 2, 3]]
lambda0B = [1, [3.2, 2.2, 1.2]]
omegam = [1, [3, 3, 3]]
omegamB = [1, [3.2, 3.2, 3.2]]



Deltapp = ["d", deltapp]
DeltappB = ["d", deltappB]
Deltap = ["d", deltap]
DeltapB = ["d", deltapB]
Delta0 = ["d", delta0]
Delta0B = ["d", delta0B]
Deltam = ["d", deltam]
DeltamB = ["d", deltamB]
Sigmap = ["s", sigmap]
SigmapB = ["s", sigmapB]
Sigma0 = ["s", sigma0]
Sigma0B = ["s", sigma0B]
Sigmam = ["s", sigmam]
SigmamB = ["s", sigmamB]
Nucleonp = ["n", nucleonp]
NucleonpB = ["n", nucleonpB]
Nucleon0 = ["n", nucleon0]
Nucleon0B = ["n", nucleon0B]
Xi0 = ["x", xi0]
Xi0B = ["x", xi0B]
Xim = ["x", xim]
XimB = ["x", ximB]
Lambda0 = ["l", lambda0]
Lambda0B = ["l", lambda0B]
Omegam = ["o", omegam]
OmegamB = ["o", omegamB]


Pip = ["M", pip]
PipB = ["M", pipB]
Pi0 = ["M", pi0]
Pi0B = ["M", pi0B]
Pim = ["M", pim]
PimB = ["M", pimB]
Eta0 = ["M", eta0]
Eta0B = ["M", eta0B]
Kaonp = ["M", kaonp]
KaonpB = ["M", kaonpB]
Kaonm = ["M", kaonm]
KaonmB = ["M", kaonmB]
Phi0 = ["M", phi0]
Phi0B = ["M", phi0B]

# %%
def Correlator(Sink, Source):

    def sgn(number):
        if number > 0:
            return '+'
        elif number < 0:
            return '-'
        else:
            return '0'

    def permutation_sign(permuted_elements):
        inversions = 0
        nF = len(permuted_elements)
        for i in range(nF):
            for j in range(i + 1, nF):
                if permuted_elements[i] > permuted_elements[j]:
                    inversions += 1
        sign = (-1) ** inversions
        return sign

    def is_valid_contraction(candidate, Start_List):
        all_elements = [elem1 for pairK in candidate for elem1 in pairK]
        return len(set(map(tuple, all_elements))) == len(Start_List)


    
    def Generate_Contraction(Start_List):
        pairs = [list(pair) for pair in combinations(Start_List, 2)]
        possible_pairs = []
        for paar_contraction in pairs:
            if np.abs(paar_contraction[0][0]) == (np.abs(paar_contraction[1][0]) + 0.2) or (np.abs(paar_contraction[0][0]) + 0.2) == np.abs(paar_contraction[1][0]):
                possible_pairs.append(paar_contraction)
        pairs2 = [list(pairX) for pairX in combinations(possible_pairs, len(Start_List) // 2)]
        final_solution = []
        for candidate in pairs2:
            if is_valid_contraction(candidate, Start_List):
                final_solution.append(candidate)
        return final_solution
    
    lSink = len(Sink)
    lSource = len(Source)
    #### Obtain the overall constant z0 ####
    z0 = 1
    total_operator = []
    source_plot = []
    sink_plot = []
    for i in range(lSink):
        z0 *= Sink[i][0]
    for j in range(lSource):
        z0 *= Source[j][0]
    #print("Overall factor: ", z0)
    #### Now combine all operators into one operator ####
    counter = 0
    for i in range(lSink):
        sub_list = []
        for quark in Sink[i][1]:
            sub_list.append([-1 * quark, counter])
            counter += 1
        total_operator.append(sub_list)
        sink_plot.append(sub_list)
    max_counter1 = counter
    counter = 0
    for j in range(lSource):
        sub_list = []
        for quark in Source[j][1]:
            sub_list.append([quark, counter])
            counter += 1
        source_plot.append(sub_list)
        total_operator.append(sub_list)
    max_counter2 = counter
    f_t_o = [quark for hadron in total_operator for quark in hadron]
    lf_t_o = len(f_t_o)
    first_Step = Generate_Contraction(f_t_o)
    second_Step = []
    sinkplot = [element for subliste in sink_plot for element in subliste]
    sourceplot = [element for subliste in source_plot for element in subliste]
    for diagram in first_Step:
        new_diagram = []
        for paar_contraction in diagram:
            if (np.abs(paar_contraction[0][0]) + 0.2) == np.abs(paar_contraction[1][0]):
                new_diagram.append(paar_contraction)
            else:
                new_diagram.append([paar_contraction[1], paar_contraction[0]])
        second_Step.append(new_diagram)
    sign_of_diagram = [0 for _ in second_Step]
    diagram_N = 0
    m_c = max_counter1 + 1
    for diagram in second_Step:
        numbers = []
        for paar_contraction in diagram:
            if paar_contraction[0][0] < 0:
                t1 = paar_contraction[0][1]
            else:
                t1 = paar_contraction[0][1] + m_c
            numbers.append(t1)
            if paar_contraction[1][0] < 0:
                t2 = paar_contraction[1][1]
            else:
                t2 = paar_contraction[1][1] + m_c
            numbers.append(t2)
        sign_of_diagram[diagram_N] = permutation_sign(numbers)
        diagram_N += 1
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    ax1.axis('off')
    ax1.set_title("Sink", loc='left')
    shift1 = 0
    shift2 = 0
    for quark in sinkplot:
        if np.abs(quark[0]) == 1:
            ax1.text(0.07, 0.8-shift1, fr'$u(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
        if np.abs(quark[0]) == 1.2:
            ax1.text(0.07, 0.8-shift1, fr'$\overline{{u}}(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
        if np.abs(quark[0]) == 2:
            ax1.text(0.07, 0.8-shift1, fr'$d(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
        if np.abs(quark[0]) == 2.2:
            ax1.text(0.07, 0.8-shift1, fr'$\overline{{d}}(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
        if np.abs(quark[0]) == 3:
            ax1.text(0.07, 0.8-shift1, fr'$s(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
        if np.abs(quark[0]) == 3.2:
            ax1.text(0.07, 0.8-shift1, fr'$\overline{{s}}(-{quark[1]})$', fontsize=13, ha='center')
            shift1 += 0.1
    ax2.axis('off')
    ax2.set_title("Source", loc='left')
    for quark in sourceplot:
        if np.abs(quark[0]) == 1:
            ax2.text(0.1, 0.8-shift2, fr'$u({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
        if np.abs(quark[0]) == 1.2:
            ax2.text(0.1, 0.8-shift2, fr'$\overline{{u}}({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
        if np.abs(quark[0]) == 2:
            ax2.text(0.1, 0.8-shift2, fr'$d({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
        if np.abs(quark[0]) == 2.2:
            ax2.text(0.1, 0.8-shift2, fr'$\overline{{d}}({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
        if np.abs(quark[0]) == 3:
            ax2.text(0.1, 0.8-shift2, fr'$s({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
        if np.abs(quark[0]) == 3.2:
            ax2.text(0.1, 0.8-shift2, fr'$\overline{{s}}({quark[1]})$', fontsize=13, ha='center')
            shift2 += 0.1
    plt.show()
    last_step = [0 for _ in second_Step]
    for i, diagram in enumerate(second_Step):
        Diagram_Propagator_Form = [0 for _ in diagram]
        for j, pair_contraction in enumerate(diagram):
            if np.abs(pair_contraction[0][0]) == 1:
                quark_line = f"u_quark_propagator({sgn(pair_contraction[0][0])}{pair_contraction[0][1]}|{sgn(pair_contraction[1][0])}{pair_contraction[1][1]})"
            if np.abs(pair_contraction[0][0]) == 2:
                quark_line = f"d_quark_propagator({sgn(pair_contraction[0][0])}{pair_contraction[0][1]}|{sgn(pair_contraction[1][0])}{pair_contraction[1][1]})"
            if np.abs(pair_contraction[0][0]) == 3:
                quark_line = f"s_quark_propagator({sgn(pair_contraction[0][0])}{pair_contraction[0][1]}|{sgn(pair_contraction[1][0])}{pair_contraction[1][1]})"
            Diagram_Propagator_Form[j] = quark_line
        last_step[i] = [sign_of_diagram[i] * z0, "[" + " ".join(Diagram_Propagator_Form) + "]"]
    return last_step

def Correlator_J(senken, quelle):
    def hadron_multiplication(hadrons):
        elements = []
        for item in hadrons:
            if isinstance(item[0], list):
                elements.append(item)
            else:
                elements.append([item])
        result0 = list(product(*elements))
        result = [list(tup) for tup in result0]
        return result
    sink0 = hadron_multiplication(senken)
    lenL = len(sink0)
    source0 = hadron_multiplication(quelle)
    lenR = len(source0)
    number_of_correlators = lenL * lenR
    Total_Wick_Contraction0 = [0 for i in range(number_of_correlators)]
    zeiger = 0
    for iL in range(lenL):
        for iR in range(lenR):
            Sink = sink0[iL]
            Source = source0[iR]
            Total_Wick_Contraction0[zeiger] = Correlator(Sink, Source)
            zeiger += 1
    Total_Wick_Contraction = [Final_element for sublist_1 in Total_Wick_Contraction0 for Final_element in sublist_1]
    return Total_Wick_Contraction

# %%
sink = [nucleonp, nucleon0, pi0] 
source = [nucleon0B, nucleonpB] 
result = Correlator_J(sink, source)
for i, x in enumerate(result):
    print(f"Diagram Number:{i} ", x[0], x[1])
# Out:
# Diagram Number:0  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:1  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:2  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:3  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:4  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:5  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:6  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:7  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:8  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:9  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:10  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:11  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:12  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:13  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:14  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:15  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:16  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:17  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:18  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:19  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:20  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:21  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:22  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:23  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:24  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:25  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:26  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:27  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:28  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:29  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:30  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:31  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:32  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:33  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:34  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:35  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:36  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:37  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:38  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:39  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:40  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:41  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:42  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:43  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:44  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:45  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:46  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:47  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:48  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:49  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:50  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:51  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:52  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:53  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:54  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:55  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:56  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:57  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:58  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:59  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:60  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:61  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:62  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+3)]
# Diagram Number:63  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:64  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:65  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:66  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:67  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:68  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+2)]
# Diagram Number:69  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:70  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+5) d_quark_propagator(-7|+1)]
# Diagram Number:71  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) d_quark_propagator(-7|-6)]
# Diagram Number:72  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:73  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:74  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:75  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:76  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:77  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:78  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:79  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:80  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:81  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:82  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:83  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:84  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:85  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:86  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:87  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:88  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:89  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:90  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:91  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:92  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:93  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:94  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:95  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:96  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:97  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:98  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:99  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:100  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:101  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:102  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:103  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:104  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:105  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:106  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:107  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:108  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:109  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:110  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+3)]
# Diagram Number:111  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:112  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:113  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:114  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:115  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:116  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+2)]
# Diagram Number:117  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:118  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+4) d_quark_propagator(-7|+1)]
# Diagram Number:119  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) d_quark_propagator(-7|-6)]
# Diagram Number:120  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:121  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:122  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:123  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:124  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:125  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|-6) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:126  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:127  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:128  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:129  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:130  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:131  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:132  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:133  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|-6) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:134  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+3)]
# Diagram Number:135  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:136  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:137  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:138  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:139  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|-6) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:140  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+2)]
# Diagram Number:141  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:142  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|-6) u_quark_propagator(-5|+0) d_quark_propagator(-7|+1)]
# Diagram Number:143  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) d_quark_propagator(-7|-6)]
# Diagram Number:144  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:145  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:146  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:147  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:148  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:149  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:150  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:151  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:152  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:153  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:154  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:155  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:156  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:157  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:158  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:159  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:160  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:161  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:162  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:163  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:164  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:165  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:166  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:167  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:168  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:169  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:170  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:171  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:172  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:173  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:174  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:175  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:176  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:177  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:178  sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:179  -sqrt(2)/2 [u_quark_propagator(-0|-6) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:180  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:181  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:182  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:183  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:184  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:185  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:186  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:187  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:188  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:189  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:190  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+5)]
# Diagram Number:191  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+4)]
# Diagram Number:192  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:193  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:194  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:195  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:196  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:197  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:198  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:199  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:200  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:201  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:202  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:203  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:204  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:205  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:206  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:207  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:208  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:209  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:210  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:211  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:212  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:213  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:214  -sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:215  sqrt(2)/2 [u_quark_propagator(-0|+0) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:216  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:217  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:218  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:219  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:220  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:221  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:222  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:223  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:224  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:225  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:226  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+5)]
# Diagram Number:227  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|+0)]
# Diagram Number:228  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:229  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:230  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:231  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:232  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:233  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:234  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:235  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:236  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:237  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:238  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+5)]
# Diagram Number:239  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+5) u_quark_propagator(-7|-6)]
# Diagram Number:240  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:241  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:242  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:243  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:244  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:245  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:246  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:247  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:248  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:249  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:250  sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:251  -sqrt(2)/2 [u_quark_propagator(-0|+4) u_quark_propagator(-1|+5) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:252  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:253  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:254  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:255  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:256  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:257  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:258  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:259  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:260  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:261  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:262  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|+4)]
# Diagram Number:263  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|-6) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|+0)]
# Diagram Number:264  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:265  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:266  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:267  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:268  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:269  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:270  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:271  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:272  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:273  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:274  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+4)]
# Diagram Number:275  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+0) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+4) u_quark_propagator(-7|-6)]
# Diagram Number:276  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:277  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+2) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:278  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:279  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+1) d_quark_propagator(-3|+3) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:280  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:281  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+1) d_quark_propagator(-4|+3) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:282  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:283  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+2) d_quark_propagator(-3|+3) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:284  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:285  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+1) d_quark_propagator(-4|+2) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
# Diagram Number:286  -sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|-6) u_quark_propagator(-7|+0)]
# Diagram Number:287  sqrt(2)/2 [u_quark_propagator(-0|+5) u_quark_propagator(-1|+4) d_quark_propagator(-2|+3) d_quark_propagator(-3|+2) d_quark_propagator(-4|+1) u_quark_propagator(-5|+0) u_quark_propagator(-7|-6)]
